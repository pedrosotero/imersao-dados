# %% [markdown]
# #Olá!
#
# Seja bem-vinda  ou bem-vindo ao notebook da aula 01, nesta aula vamos realizar nossa primeira análise de dados e no final já seremos capazes de tirar algumas conclusões.
#
# Nós desenvolveremos nosso projeto aqui no google colaboratory, assim podemos mesclar células contendo textos em formato markdown e células de código, além disso você não precisa instalar nada na sua máquina. Então, que tal começar testando algumas linhas de código?
#
# No campo abaixo temos o que chamamos de célula. Na célula nós podemos digitar textos, cálculos e códigos.
#
# Após eu introduzir o que eu quero na célula eu vou rodar esse conteúdo. Para isso podemos usar o atalho SHIFT + ENTER, ou até mesmo clicar no símbolo de play no canto esquerdo da célula. Na primeira vez que rodamos algo no nosso notebook ele vai demorar um pouco mais de tempo, e isso ocorre porque o google está alocando uma máquina virtual para nós utilizarmos.
#
# Vamos então fazer alguns testes, como os exemplos abaixo:

# %%
10 + 10
# Out:
# 20

# %%
'Thiago'
# Out:
# 'Thiago'

# %% [markdown]
# # Importando os dados
#
# Nessa imersão nós vamos mergulhar no universo da biologia e da biotecnologia e explorar uma base de dados da área.
#
# Para a nossa análise, está faltando então os dados. Para conseguirmos esses dados vamos acessar o Github, nesse link:
#
# https://github.com/alura-cursos/imersaodados3/tree/main/dados
#
# Então, agora vamos importar essa base de dados para dentro do nosso notebook. Para juntar essas informações vamos utilizar nossa famosa biblioteca do "Pandas".
# Vamos importar essa biblioteca através do seguinte código:

# %%
import pandas as pd

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [23814 rows x 877 columns]

# %% [markdown]
# Observe que imprimimos agora todas as nossas linhas e colunas da nossa tabela.
#
# Aqui observamos que temos dados referentes a ID, tratamento, tempo, dose, entre outras.
#
# Para nos auxiliar na visualização e na identificação das colunas dos dados que vamos trabalhar, faremos um recorte, uma espécie de cabeçalho, com 5 linhas, e para isso usamos o seguinte comando:

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# Quando estávamos trabalhando com o conjunto total de dados nós tínhamos a informação do número total de linhas e colunas. Porém, agora com o head, nós perdemos essa informação. Então, caso você queira recuperar a informação do total de linhas e colunas basta utilizar:

# %%
dados.shape
# Out:
# (23814, 877)

# %% [markdown]
# Então, agora vamos voltar para o nosso problema.
#
# Nós queremos iniciar fazendo uma análise dos dados que estamos tratando. Vamos começar selecionando só uma coluna, para entendermos do que ela está tratando.
#
# Vamos iniciar com a coluna tratamento. Para isso vamos digitar:

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %% [markdown]
# Esse tipo de informação, da coluna, é o que chamamos de 'série'. Já a tabela inteira nós chamos de 'dataframe'.
#
# Agora para vermos os tipos específicos de informação que temos dentro dessa coluna vamos digitar:

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %% [markdown]
# A resposta foi dada no formato de array, que nada mais é do que um vetor, ou seja, um tipo de estrutura de dados.
#
# Observe que encontramos dois tipos: 'com droga' e 'com controle'.
#
# Com droga, como o próprio nome nos diz, é quando estamos aplicando algum tipo de droga para a amostra. Já com o controle é uma técnica estatística em que isolamos as outras varíaveis e observamos apenas a variável de interesse.

# %% [markdown]
# Agora vamos analisar a coluna do tempo:

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %% [markdown]
# Encontramos 3 tipos de informação nessa coluna: 24, 72 e 48. O que pode nos indicar o tempo, provavelmente em horas, de intervalo que foi administrada a dose de medicamentos ou drogas.
#
# É interessante que observamos o comportamento das células com essa diferença de tempo, já que se analisássemos num período diferente poderia não dar tempo suficiente pra célula manifestar o determinado comportamento.

# %% [markdown]
# Além do tempo, podemos analisar também a coluna de dose:

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %% [markdown]
# Aqui obtemos dois tipos de doses diferentes, d1 e d2, mas não conseguimos afirmar nada categoricamente de antemão.

# %% [markdown]
# Vamos então analisar a categoria droga:

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %% [markdown]
# Agora com a resposta de ```dados['droga'].unique()``` obtivemos essa série de códigos como resposta. Talvez esses números foram codificados na tentativa de anonimizar os tipos de drogas usadas, para tentar evitar qualquer tipo de viés na análise dos resultados.
#
# Há uma série de regras quando alguns experimentos são feitos, evitando mostrar dados como nome, sexo, e outros fatores, dependendo da análise a ser feita, para que sejam evitados vieses.

# %% [markdown]
# Vamos analisar a coluna nomeada como g-0 agora:

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %% [markdown]
# Só olhando fica difícil tentar deduzir o que esses números representam. Então, nesse ponto, com o auxílio da Vanessa, especialista, conseguimos a informação que essa letra 'g' da coluna remete à palavra gene. Ou seja, esses números nos dizem a expressão de cada gene frente as drogas ou a exposição.
#
# Quando subimos de volta na tabela, percebemos que há diversos valores, inclusive com várias casas decimais. Aparentemente esses números foram "arredondados", normalizados, para podermos compará-los de alguma forma.
#
# Então, até agora na nossa análise, já conseguimos identificar e entender as informações de diferentes colunas; as colunas que nos indicam os tratamentos, as drogas, o tempo, e depois as respostas genéticas, que tem a letra g no ínicio do seu nome.
#
# Outro tipo de análise que podemos fazer agora é entender a distribuição dessas informações. Por exemplo, podemos saber quantos experimentos temos utilizando droga e quantos não utilizam; quantos usam o d1, e quantos utilizam o d2, e assim por diante.
#
# Como podemos fazer isso? Vamos utilizar esse código:

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %% [markdown]
# Agora, em vez de usarmos o ```.unique``` no código, nós utilizamos o ```.value_counts``` já que nosso objetivo era contar a quantidade de valores que apareciam nas colunas, nesse caso, na coluna ```tratamento```.
#
# No resultado ele retornou 2 linhas: uma com a quantidade de elementos que temos, ou seja, com a minha frequência, na categoria ```com_droga``` e a outra com a quantidade que temos na categoria ```com_controle```.
#
# Houve uma grande diferença no resultado dessas categorias, não é mesmo? Isso é, no mínimo, curioso. Então, Guilherme vai nos sugerir um desafio, de investigar o por quê dessa diferença tão grande.
#
# Nesse momento o Thiago já escreve outros dois desafios, o desafio #2 e o desafio #3. E a Vanessa também deixa o seu, desafio #4. Todos os desafios dessa aula estão escritos no final desse notebook.

# %% [markdown]
# Será que essa diferença entre os valores dentro das categorias continuam tão desproporcionais? Vamos investigar a categoria ```dose```:

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %% [markdown]
# Nesse ponto parece que as coisas já estão mais equilibradas. Mas somente com o número é difícil fazermos uma leitura mais aprofundada. Então, nesse momento, vamos resolver um dos desafios deixados. Então, se até aqui você ainda nao resolveu os desafios do vídeo e nao quer receber um spoiler, pare aqui e tente resolvê-los primeiro.

# %% [markdown]
# Para entendermos melhor e fazer um comparativo é legal traçarmos a proporção entre os dados. Vamos escrever o código agora, setando como parâmetro, dentro dos parênteses o ```normalize = True``` :

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# Temos agora os dados "normalizados". Podemos interpretar utilizando a porcentagem (multiplicando por 100), o que nos daria algo em torno de 92% versus 8% (aproximadamente), mostrando o tamanho da desproporção.

# %% [markdown]
# Vamos fazer o mesmo agora com a coluna ```dose```:

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %% [markdown]
# Temos aqui o resultado. Inclusive, como mini-desafio, você pode fazer o mesmo processo com as outras colunas.
#
# Certo, mas geralmente, quando há a trasmissão dessas informações, vemos uma série de gráficos. E, geralmente, é usado aquele gráfico que parece uma torta, ou uma pizza.
#
# Vamos então plotar um gráfico dessa tipo, com o seguinte código:

# %%
dados['tratamento'].value_counts().plot.pie()

# %% [markdown]
# Aqui, em azul, nós temos a quantidade de tratamento com drogas(que é muito maior, em proporção), e em laranja temos o tratamento "com controle". Ficou até parecendo um pacman, hehe.
#
# Vamos aproveitar e analisar as outras informações com os gráficos também, para vermos o que acontece. Vamos analisar a coluna tempo:

# %%
dados['tempo'].value_counts().plot.pie()

# %% [markdown]
# Repare como ficou difícil a olho nú identificarmos qual observação é maior através do gráfico. Esse tipo de gráfico pode acabar dificultando um pouco a análise, especialmente quando as informações estão melhor balanceadas.
#
# Além de identificar a quantidade de horas observadas, nós não conseguimos extrair mais nenhuma informação desse gráfico. Inclusive, nós temos uma espécie de regrinha, que diz que quando formos fazer algum tipo de análise, procurarmos evitar o uso de gráficos que nos remetem a comida, como por exemplo: rosca, pizza, torta, e assim por diante.
#
# Então qual tipo de gráfico poderíamos utlizar para melhorarmos nossa visualização? Vamos utilizar o gráfico de barras, através deste código:

# %%
dados['tempo'].value_counts().plot.bar()

# %% [markdown]
# Agora sim conseguimos identificar com mais facilidade qual observação tem a sua maior frequência. Na verdade a quantidade de horas com o maior número de observações foi a de 48.
#
# No eixo y temos o número que nos remete ao número de observações. Então podemos observar que tivemos pouco mais de 8000 observações relativas às 48 horas.
#
# Então, o gráfico de barras acabou sendo muit mais útil, nesse caso, do que o gráfico de pizza.

# %% [markdown]
# Ao longo da aula nós falamos sobre a expressão gênica. Se nós voltarmos à tabela, na coluna g-0, nós temos alguns valores dentro de um intervalo definido. Para não termos valores muito distantes entre si, é bastante comum no meio científico que haja uma normalização dos resultados, para criamos um intervalo que não seja tão grande, em que o meio dessa distribuição seja o 0.
#
# Como nós podemos saber em quais linhas dessa coluna, o meu valor está acima de 0?
#
# Vamos fazer uma consulta nos nossos dados, da seguinte maneira:

# %%
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# Dessa maneira, temos somente as 5 primeiras linhas com o valores maiores do que 0 na coluna g-0, com a ajuda dessa máscara com o código ```[dados['g-0']>0]```.
#
# Dessa mesma forma que aplicamos essa máscara, podemos utilizar o mesmo caminho, ou outras 'querys', para responder várias outras perguntas.
#
# Assim, temos outro desafio, o #5, de procurar na documentação do pandas o método query.
#
# Além desse temos outros desafios, o #6 e o #7 e o #8, todos eles estão logo abaixo.

# %%
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [23814 rows x 877 columns]

# %% [markdown]
# ###Desafio 01: Investigar por que a classe tratamento é tão desbalanceada?
#
# ###Desafio 02: Plotar as 5 últimas linhas da tabela
#
# ###Desafio 03: Proporção das classes tratamento.
#
# ###Desafio 04: Quantos tipos de drogas foram investigados.
#
# ###Desafio 05: Procurar na documentação o método query(pandas).
#
# ###Desafio 06: Renomear as colunas tirando o hífen.
#
# ###Desafio 07: Deixar os gráficos bonitões. (Matplotlib.pyplot)
#
# ###Desafio 08: Resumo do que você aprendeu com os dados

# %% [markdown]
# #Desafio 01: Investigar por que a classe tratamento é tão desbalanceada?
#
#
# ---
#
#
# Primeiramente, peguei algumas drogas específicas pra analisar e percebi que elas foram somente utilizadas com o tipo de tratamento **'com_droga'**.
#
# Depois analisei todas as linhas que continham o tratamento **'com_controle'** e cheguei a conclusão de que todos os casos do tratamento com controle haviam utilizado a droga **'cacb2b860'**.
#
# ## Conclusão
#
# O desbalanceamento da quantidade de dados da coluna tratamento se deve ao fato de que o método **'com_controle'** foi apenas utilizado com a droga **'cacb2b860'**, enquanto todas as outras drogas utilizaram o método **'com_droga'**.

# %%
# Analisando a droga b68db1d53
dados[dados['droga'] == 'b68db1d53']
# Out:
#                  id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 6175   id_4257c8753  com_droga     48   D2  ...  0.5498  0.5549  0.7475  0.8182
# 13774  id_948ea9d02  com_droga     48   D1  ... -0.2858  0.2747 -0.0332  0.3551
# 14257  id_997d9f25d  com_droga     72   D2  ...  0.7134 -0.4061  0.6136 -0.3192
# 20190  id_d8c3cebd1  com_droga     24   D2  ...  0.1703  0.3615  1.1420  0.9481
# 22507  id_f1c7f3184  com_droga     72   D1  ...  1.9420  0.9040  0.3415  0.6709
#
# [6 rows x 877 columns]

# %%
# Analisando a droga df89a8e5a
dados[dados['droga'] == 'df89a8e5a']
# Out:
#                  id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 1      id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 5389   id_3a1a0a94a  com_droga     24   D2  ...  0.5564  0.1029 -0.1804  0.1189
# 6070   id_416ba6804  com_droga     24   D1  ...  0.9396 -0.1500  0.5778 -0.8005
# 12328  id_84cfb2d4e  com_droga     48   D2  ...  1.1490  0.9931 -0.5764  0.1321
# 14089  id_97b32c381  com_droga     48   D1  ...  0.2351 -0.1712  0.7836  0.2187
# 19987  id_d6421128d  com_droga     72   D2  ... -0.2848  0.1784 -0.0047 -0.5186
#
# [6 rows x 877 columns]

# %%
# Analisando somente os casos de tratamento com_controle
dados[dados['tratamento'] == 'com_controle']
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# 47     id_008a986b7  com_controle     48   D2  ... -0.4979  0.5281 -0.9245 -0.9367
# 63     id_009d8340f  com_controle     24   D2  ...  0.0949  0.2000 -0.4326  0.9364
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23729  id_ff1f9e5fc  com_controle     24   D1  ...  0.2131 -0.1419 -0.2422  0.0457
# 23747  id_ff469c482  com_controle     72   D1  ... -0.9630  0.8872 -0.0742 -0.6777
# 23768  id_ff89331ca  com_controle     72   D2  ...  0.9517 -0.8110 -0.1748 -0.3626
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
#
# [1866 rows x 877 columns]

# %%
# Provando que todos os casos de com_controle utilizaram a mesma droga
# mostrando todos os valores únicos da coluna droga que tiveram o
# tratamento com controle
dados[dados['tratamento'] == 'com_controle']['droga'].unique()
# Out:
# array(['cacb2b860'], dtype=object)

# %% [markdown]
# #Desafio 02: Plotar as 5 últimas linhas da tabela
#
#
# ---
#
#
# Para plotar as ultimas 5 linhas, usa-se o comando `tail()`.
# Como parâmetro podemos passar o número de linhas que queremos, mas 5 ja é o padrão.

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# #Desafio 03: Proporção das classes tratamento.
#
#
# ---
#
# Usei o método `value_counts()` com `normalize = True` para obter a porcentagem de cada tratamento. Depois utilizei o gráfico de barras horizontal (`plot.barh()`) por julgar menos confuso de enxergar os dados

# %%
dados['tratamento'].value_counts(normalize=True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['tratamento'].value_counts().plot.barh()

# %% [markdown]
# #Desafio 04: Quantos tipos de drogas foram investigados.
#
#
# ---
#
# Há duas formas de obter esse resultado:
#
#
# * Utilizando o método `len()` do próprio python na lista de valores únicos da coluna droga
# * Utilizando o método `nunique()` do pandas na coluna 'droga' do dataframe
#
# ##Conclusão
#
# Foram investigados **3289** tipos diferentes de droga.

# %%
len(dados['droga'].unique()) # len()
# Out:
# 3289

# %%
dados['droga'].nunique() # nunique()
# Out:
# 3289

# %% [markdown]
# #Desafio 05: Procurar na documentação o método query(pandas).
#
#
# ---
#
# **Método utilizado para aplicar expressões booleanas em colunas.**
#
#
# ---
#
# Como foi dito na aula, nomes de colunas com hífen geram problemas no método, mas a documentação mostra que, em alguns casos, ao colocar o nome com caracteres problemáticos entre (``), podemos usar sem alterá-los.
#
# *Exemplos abaixo:*

# %%
# Nomes de colunas com hífen são problemáticos no método query()
dados.query('g-1 == g-0')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     187             if self.has_resolvers:
# --> 188                 return self.resolvers[key]
#     189
#
# /usr/lib/python3.7/collections/__init__.py in __getitem__(self, key)
#     915                 pass
# --> 916         return self.__missing__(key)            # support subclasses that define __missing__
#     917
#
# /usr/lib/python3.7/collections/__init__.py in __missing__(self, key)
#     907     def __missing__(self, key):
# --> 908         raise KeyError(key)
#     909
#
# KeyError: 'g'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     198                 # e.g., df[df > 0]
# --> 199                 return self.temps[key]
#     200             except KeyError as err:
#
# KeyError: 'g'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# <ipython-input-53-162e089c6ea6> in <module>()
# ----> 1 dados.query('g-1 == `g-0`')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    3343         kwargs["level"] = kwargs.pop("level", 0) + 1
#    3344         kwargs["target"] = None
# -> 3345         res = self.eval(expr, **kwargs)
#    3346
#    3347         try:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    3473         kwargs["resolvers"] = kwargs.get("resolvers", ()) + tuple(resolvers)
#    3474
# -> 3475         return _eval(expr, inplace=inplace, **kwargs)
#    3476
#    3477     def select_dtypes(self, include=None, exclude=None) -> "DataFrame":
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     339         )
#     340
# --> 341         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     342
#     343         # construct the engine and evaluate the parsed expression
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in __init__(self, expr, engine, parser, env, level)
#     785         self.parser = parser
#     786         self._visitor = _parsers[parser](self.env, self.engine, self.parser)
# --> 787         self.terms = self.parse()
#     788
#     789     @property
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in parse(self)
#     804         Parse an expression.
#     805         """
# --> 806         return self._visitor.visit(self.expr)
#     807
#     808     @property
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     396         method = "visit_" + type(node).__name__
#     397         visitor = getattr(self, method)
# --> 398         return visitor(node, **kwargs)
#     399
#     400     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in visit_Module(self, node, **kwargs)
#     402             raise SyntaxError("only a single expression is allowed")
#     403         expr = node.body[0]
# --> 404         return self.visit(expr, **kwargs)
#     405
#     406     def visit_Expr(self, node, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     396         method = "visit_" + type(node).__name__
#     397         visitor = getattr(self, method)
# --> 398         return visitor(node, **kwargs)
#     399
#     400     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in visit_Expr(self, node, **kwargs)
#     405
#     406     def visit_Expr(self, node, **kwargs):
# --> 407         return self.visit(node.value, **kwargs)
#     408
#     409     def _rewrite_membership_op(self, node, left, right):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     396         method = "visit_" + type(node).__name__
#     397         visitor = getattr(self, method)
# --> 398         return visitor(node, **kwargs)
#     399
#     400     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in visit_Compare(self, node, **kwargs)
#     697             op = self.translate_In(ops[0])
#     698             binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 699             return self.visit(binop)
#     700
#     701         # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     396         method = "visit_" + type(node).__name__
#     397         visitor = getattr(self, method)
# --> 398         return visitor(node, **kwargs)
#     399
#     400     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in visit_BinOp(self, node, **kwargs)
#     518
#     519     def visit_BinOp(self, node, **kwargs):
# --> 520         op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     521         left, right = self._maybe_downcast_constants(left, right)
#     522         return self._maybe_evaluate_binop(op, op_class, left, right)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in _maybe_transform_eq_ne(self, node, left, right)
#     437     def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     438         if left is None:
# --> 439             left = self.visit(node.left, side="left")
#     440         if right is None:
#     441             right = self.visit(node.right, side="right")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     396         method = "visit_" + type(node).__name__
#     397         visitor = getattr(self, method)
# --> 398         return visitor(node, **kwargs)
#     399
#     400     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in visit_BinOp(self, node, **kwargs)
#     518
#     519     def visit_BinOp(self, node, **kwargs):
# --> 520         op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     521         left, right = self._maybe_downcast_constants(left, right)
#     522         return self._maybe_evaluate_binop(op, op_class, left, right)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in _maybe_transform_eq_ne(self, node, left, right)
#     437     def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     438         if left is None:
# --> 439             left = self.visit(node.left, side="left")
#     440         if right is None:
#     441             right = self.visit(node.right, side="right")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     396         method = "visit_" + type(node).__name__
#     397         visitor = getattr(self, method)
# --> 398         return visitor(node, **kwargs)
#     399
#     400     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in visit_Name(self, node, **kwargs)
#     531
#     532     def visit_Name(self, node, **kwargs):
# --> 533         return self.term_type(node.id, self.env, **kwargs)
#     534
#     535     def visit_NameConstant(self, node, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/ops.py in __init__(self, name, env, side, encoding)
#      82         tname = str(name)
#      83         self.is_local = tname.startswith(_LOCAL_TAG) or tname in _DEFAULT_GLOBALS
# ---> 84         self._value = self._resolve_name()
#      85         self.encoding = encoding
#      86
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/ops.py in _resolve_name(self)
#      99
#     100     def _resolve_name(self):
# --> 101         res = self.env.resolve(self.local_name, is_local=self.is_local)
#     102         self.update(res)
#     103
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     202                 from pandas.core.computation.ops import UndefinedVariableError
#     203
# --> 204                 raise UndefinedVariableError(key, is_local) from err
#     205
#     206     def swapkey(self, old_key: str, new_key: str, new_value=None):
#
# UndefinedVariableError: name 'g' is not defined

# %%
# Mesmo comando com os nomes das colunas entre ``
# Retorna as linhas em que g-0 é igual a g-1
dados.query('`g-1` == `g-0`')
# Out:
#                  id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 5153   id_376c2e3ed  com_droga     24   D2  ... -1.4050 -0.0013 -0.4876  0.4943
# 12844  id_8a4a51ad5  com_droga     72   D1  ... -0.7688 -0.0054 -0.0738  0.3623
#
# [2 rows x 877 columns]

# %%
# Retorna as linhas em que o g-0 é positivo
dados.query('`g-0` > 0')
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6      id_001bd861f     com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23807  id_fff7e6992     com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444     com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
#
# [11769 rows x 877 columns]

# %% [markdown]
# #Desafio 06: Renomear as colunas tirando o hífen.
#
#
# ---
#
# Utilizei um dictionary compreehension para gerar um dicionário contendo o nome antigo da coluna como chave e o nome novo como valor utilizando o método de string `replace()`. Após isso, usei o método `rename()` nos dados, passando o dicionário como argumento do parâmetro columns e `inplace=True` para já alterar no dataframe, sem fazer uma cópia.

# %%
index = {nome: nome.replace('-', '') for nome in dados.columns} # Gerando o dicionário dos nomes das colunas
dados.rename(columns=index, inplace=True)     # Renomeando as colunas no dataframe de origem
dados
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [23814 rows x 877 columns]

# %% [markdown]
# #Desafio 07: Deixar os gráficos bonitões. (Matplotlib.pyplot)
#
#
# ---
#
# Utilizei a bibliotecla *matplotlib* para plotar os gráficos.
#
# Refiz o gráfico de proporção dos tratamentos e fiz os gráficos de Doses e Tempo.

# %%
import matplotlib.pyplot as plt # Importando a biblioteca

# Definindo variáveis para guardar os valores únicos das colunas desejadas e
# seus valores
tratamento = dados['tratamento'].value_counts()
tempo = dados['tempo'].value_counts()
dose = dados['dose'].value_counts()

# Criação da figure para armazenar os 3 gráficos
fig, ax = plt.subplots(1, 3,figsize=(22, 5))

# Primeiro gráfico
ax[0].barh(tratamento.index, tratamento.values, color='orange')
ax[0].set_title("Tratamentos", size=20)
ax[0].set_xticks(range(0, 22501, 2500))
ax[0].grid()

# Segundo gráfico
ax[1].barh(dose.index, dose.values, color='green')
ax[1].set_title("Doses", size=20)
ax[1].grid()

# Terceiro gráfico
tempo.plot.bar(color='purple')
ax[2].set_title("Tempo", size=20)
ax[2].grid()

# %% [markdown]
# #Desafio 08: Resumo do que você aprendeu com os dados
#
#
# ---
# * Como criar um dataframe a partir de um arquivo csv da internet
# * Ver o número de linhas e colunas do dataframe
# * Checar os valores unicos de uma coluna e suas proporções
# * Renomear colunas
# * Criar gráficos a partir dos dados
# * Obter linhas aplicando uma operação booleana
# * Analisar relações entre colunas
